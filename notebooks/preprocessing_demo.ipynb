# %% [markdown]
# # Loan preprocessing demo

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
from src.train_pipeline import train_and_evaluate

model, accuracy = train_and_evaluate()
print(f"Test accuracy: {accuracy:.4f}")
